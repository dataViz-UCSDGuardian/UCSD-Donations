# %%
# Get this figure: fig = py.get_figure("https://plot.ly/~tarzzz/1344/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~tarzzz/1344/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="Bar Graph with Legend (1)", fileopt="extend"))
# Get y data of first trace: y1 = py.get_figure("https://plot.ly/~tarzzz/1344/").get_data()[0]["y"]

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in(username = 'mec029', api_key = '5lcnm610z2')
trace1 = Bar(
    x=[2012, 2013, 2014, 2015],
    y=[2, 2, 2, 2],
    name='data1',
    orientation='v',
    showlegend=True,
    visible=True,
    xaxis='x1',
    yaxis='y1'
)
trace2 = Bar(
    x=[2012, 2013, 2014, 2015],
    y=[2, 5, 8, 11],
    name='data2',
    orientation='v',
    showlegend=True,
    visible=True,
    xaxis='x1',
    yaxis='y1'
)
trace3 = Bar(
    x=[2012, 2013, 2014, 2015],
    y=[3, 6, 9, 12],
    name='data3',
    orientation='v',
    showlegend=True,
    visible=True,
    xaxis='x1',
    yaxis='y1'
)
data = Data([trace1, trace2, trace3])
layout = Layout(
    annotations=Annotations([
        Annotation(
            x=0.517,
            y=0.935,
            align='center',
            showarrow=False,
            text='<b>Bar Graph with Legend</b>',
            xanchor='center',
            xref='paper',
            yanchor='bottom',
            yref='paper'
        )
    ]),
    barmode='stack',
    height=630,
    legend=Legend(
        xanchor='left',
        yanchor='bottom'
    ),
    margin=Margin(
        r=0,
        t=0,
        b=0,
        l=0,
        pad=0
    ),
    showlegend=True,
    title='<b>Bar Graph with Legend</b>',
    titlefont=dict(
        color='rgba(0,0,0,0)'
    ),
    width=840,
    xaxis1=XAxis(
        anchor='y1',
        domain=[0.13, 0.905],
        side='bottom',
        type='linear'
    ),
    yaxis1=YAxis(
        anchor='x1',
        domain=[0.11, 0.925],
        side='left',
        type='linear'
    )
)
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig)
